# %%
#clean data and make simple classifier

import pandas as pd

df1 = pd.read_csv('./data/Kanye_West.csv')
df2 = pd.read_csv('./data/HAIM.csv')


df1.head()
# Out:
#    Unnamed: 0      artist  artist_id  album  album_id          song  \
# 0           0  Kanye West   33091467  Donda  46691158   Donda Chant
# 1           1  Kanye West   33091467  Donda  46691158          Jail
# 2           2  Kanye West   33091467  Donda  46691158  God Breathed
# 3           3  Kanye West   33091467  Donda  46691158  Off The Grid
# 4           4  Kanye West   33091467  Donda  46691158     Hurricane
#
#      song_id                                             lyrics
# 0  222687538  Donda, Donda\nDonda\n\nDonda, Donda, Donda, Do...
# 1  222687539  Take what you want\nTake everything\nTake what...
# 2  222687540  I know God breathed on this\nI know God breath...
# 3  222687541  Yeah\n\nWhat?\n\nWe off the grid, grid, grid\n...
# 4  222687542  See this in 3D, all lights out for me\nAll lig...

# %%
df2.head()
# Out:
#    Unnamed: 0 artist  artist_id         album  album_id           song  \
# 0           0   HAIM   14314243  I Know Alone  37212642   I Know Alone
# 1           1   HAIM   14314243  I Know Alone  37212642    Don't Wanna
# 2           2   HAIM   14314243  I Know Alone  37212642      The Steps
# 3           3   HAIM   14314243  I Know Alone  37212642  Now I'm In It
# 4           4   HAIM   14314243  I Know Alone  37212642     Hallelujah
#
#      song_id                                             lyrics
# 0  195841352  Been a couple days since I've been out\nCallin...
# 1  196877715  Ooh, you, you did me so bad\nWhen I was in the...
# 2  194157593  So baby, when I'm near you\nYou can't feel me,...
# 3  194157619  Looking in the mirror again and again\nWishing...
# 4  194157620  I met two angels, but they were in disguise\nT...

# %%
df1['song'].unique()
# Out:
# array(['Donda Chant', 'Jail', 'God Breathed', 'Off The Grid', 'Hurricane',
#        'Praise God', 'Jonah', 'Ok Ok', 'Junya', 'Believe What I Say',
#        'Heartless', 'Good Morning', 'Champion', 'Stronger', 'I Wonder',
#        'Good Life', "Can't Tell Me Nothing", 'Barry Bonds',
#        'Drunk and Hot Girls', 'Flashing Lights', 'Everything I Am',
#        'All Of The Lights - Album Version (Edited)', 'Say You Will',
#        'Welcome To Heartbreak', 'Amazing', 'Love Lockdown', 'Paranoid',
#        'RoboCop', 'Street Lights', 'Bad News', 'See You In My Nightmares',
#        'Wake Up Mr. West', "Heard 'Em Say", 'Touch The Sky',
#        'Gold Digger', 'Skit #1 (Kanye West/Late Registration)',
#        'Drive Slow', 'My Way Home', 'Crack Music', 'Roses',
#        'Bring Me Down', 'Ultralight Beam',
#        'Father Stretch My Hands Pt. 1', 'Pt. 2', 'Famous', 'Feedback',
#        'Low Lights', 'Highlights', 'Freestyle 4', 'I Love Kanye', 'Waves',
# ...

# %%
df1.shape
# Out:
# (82, 8)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# artist        0
# artist_id     0
# album         0
# album_id      0
# song          0
# song_id       0
# lyrics        7
# dtype: int64

# %%
# Drop rows where song lyrics is nan

df1.dropna(subset=['lyrics'],inplace=True)

# %%
df1.shape
# Out:
# (75, 8)

# %%
df1_usong = df1.drop_duplicates(subset=['song'])

df1_usong.shape
# Out:
# (68, 8)

# %%
df1_usong.head(10)
# Out:
#    Unnamed: 0      artist  artist_id  album  album_id                song  \
# 0           0  Kanye West   33091467  Donda  46691158         Donda Chant
# 1           1  Kanye West   33091467  Donda  46691158                Jail
# 2           2  Kanye West   33091467  Donda  46691158        God Breathed
# 3           3  Kanye West   33091467  Donda  46691158        Off The Grid
# 4           4  Kanye West   33091467  Donda  46691158           Hurricane
# 5           5  Kanye West   33091467  Donda  46691158          Praise God
# 6           6  Kanye West   33091467  Donda  46691158               Jonah
# 7           7  Kanye West   33091467  Donda  46691158               Ok Ok
# 8           8  Kanye West   33091467  Donda  46691158               Junya
# 9           9  Kanye West   33091467  Donda  46691158  Believe What I Say
#
#      song_id                                             lyrics
# 0  222687538  Donda, Donda\nDonda\n\nDonda, Donda, Donda, Do...
# ...

# %%
# New lrycis str col
df1_usong['lyric_str'] = [' '.join(text.split('\n')) for text in df1_usong['lyrics']]

df1_usong.head()
# Out:
# C:\Users\Valentin Baltazar\AppData\Local\Temp\ipykernel_23768\1764312726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_usong['lyric_str'] = [' '.join(text.split('\n')) for text in df1_usong['lyrics']]
#    Unnamed: 0      artist  artist_id  album  album_id          song  \
# 0           0  Kanye West   33091467  Donda  46691158   Donda Chant
# 1           1  Kanye West   33091467  Donda  46691158          Jail
# 2           2  Kanye West   33091467  Donda  46691158  God Breathed
# 3           3  Kanye West   33091467  Donda  46691158  Off The Grid
# 4           4  Kanye West   33091467  Donda  46691158     Hurricane
#
#      song_id                                             lyrics  \
# ...

# %%
df1_usong['lyric_str'][10]
# Out:
# "In the night I hear 'em talk The coldest story ever told Somewhere far along this road He lost his soul to a woman so heartless How could you be so heartless? Oh, how could you be so heartless?  How could you be so, cold as the winter wind when it breeze, yo Just remember that you talkin' to me though You need to watch the way you talkin' to me, yo I mean after all the things that we've been through I mean after all the things we got into Ayo, I know of some things that you ain't told me Ayo, I did some things, but that's the old me  And now you wanna get me back and you gon' show me So you walk around like you don't know me You got a new friend, well, I got homies But in the end it's still so lonely  In the night I hear 'em talk The coldest story ever told Somewhere far along this road ..."

# %%
df1_usong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 71
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  70 non-null     int64
#  1   artist      70 non-null     object
#  2   artist_id   70 non-null     int64
#  3   album       70 non-null     object
#  4   album_id    70 non-null     int64
#  5   song        70 non-null     object
#  6   song_id     70 non-null     int64
#  7   lyrics      63 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 4.9+ KB

# %%
df1_usong['lyrics'].astype()

# %%
dtype_counts = df1_usong['lyrics'].apply(type).value_counts()

# Print the counts
print("String:", dtype_counts)
# print("Other data types:", sum(dtype_counts) - dtype_counts.get(str, 0))
# Out:
# String: lyrics
# <class 'str'>      63
# <class 'float'>     7
# Name: count, dtype: int64

# %%
for i in df1_usong['lyrics']:
    print(type(i))
    if type(i) == float:
        # print(type(i))
        print(i)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# nan
# <class 'str'>
# <class 'float'>
# nan
# <class 'str'>
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'str'>
# <class 'float'>
# nan
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# nan
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...
